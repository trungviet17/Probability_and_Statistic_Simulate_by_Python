# %% [markdown]
# # Introduction to Xarray

# %%
import xarray as xr
import pandas as pd
import numpy as np

# %% [markdown]
# ## Structure

# %% [markdown]
# ### DataArray

# %%
# coords : là tập những index dùng để trỏ vào array

d = xr.DataArray(np.random.rand(4,2), coords= {'x': ['a', 'b', 'c', 'd'], 'y' : [ 'e', 'f']}, dims= ['x', 'y'])
d
# Out:
# <xarray.DataArray (x: 4, y: 2)>
# array([[0.57996505, 0.94532263],
#        [0.4047028 , 0.35313625],
#        [0.97968929, 0.9130374 ],
#        [0.38888741, 0.36180792]])
# Coordinates:
#   * x        (x) <U1 'a' 'b' 'c' 'd'
#   * y        (y) <U1 'e' 'f'

# %%
d.loc['a','e']
# Out:
# <xarray.DataArray ()>
# array(0.57996505)
# Coordinates:
#     x        <U1 'a'
#     y        <U1 'e'

# %%
print(d.coords)
print(d.dims)
print(d.name)
print(d.attrs)
# Out:
# Coordinates:
#   * x        (x) <U1 'a' 'b' 'c' 'd'
#   * y        (y) <U1 'e' 'f'
# ('x', 'y')
# None
# {}

# %% [markdown]
# ### DataSet

# %%
temp = 15 + 8 * np.random.randn(2, 2, 3)

precip = 10 * np.random.rand(2, 2, 3)

lon = [[-99.83, -99.32], [-99.79, -99.23]]

lat = [[42.25, 42.21], [42.63, 42.59]]

ds = xr.Dataset(
     {
        "temperature": (["x", "y", "time"], temp),
        "precipitation": (["x", "y", "time"], precip),
    },
    coords={
        "lon": (["x", "y"], lon),
        "lat": (["x", "y"], lat),
        "time": pd.date_range("2014-09-06", periods=3),
        "reference_time": pd.Timestamp("2014-09-05"),
    },
)

ds
# Out:
# <xarray.Dataset>
# Dimensions:         (x: 2, y: 2, time: 3)
# Coordinates:
#     lon             (x, y) float64 -99.83 -99.32 -99.79 -99.23
#     lat             (x, y) float64 42.25 42.21 42.63 42.59
#   * time            (time) datetime64[ns] 2014-09-06 2014-09-07 2014-09-08
#     reference_time  datetime64[ns] 2014-09-05
# Dimensions without coordinates: x, y
# Data variables:
#     temperature     (x, y, time) float64 8.586 21.33 8.045 ... 8.022 9.973 10.71
#     precipitation   (x, y, time) float64 3.824 9.208 4.681 ... 1.863 1.283 8.055

# %% [markdown]
# ## Index, Select and Drop

# %%
ds['temperature'][0,0,1]
# Out:
# <xarray.DataArray 'temperature' ()>
# array(21.32961588)
# Coordinates:
#     lon             float64 -99.83
#     lat             float64 42.25
#     time            datetime64[ns] 2014-09-07
#     reference_time  datetime64[ns] 2014-09-05

# %%
ds.sel(x = 0, y = 1)
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 3)
# Coordinates:
#     lon             float64 -99.32
#     lat             float64 42.21
#   * time            (time) datetime64[ns] 2014-09-06 2014-09-07 2014-09-08
#     reference_time  datetime64[ns] 2014-09-05
# Data variables:
#     temperature     (time) float64 15.58 21.41 13.8
#     precipitation   (time) float64 7.293 3.407 8.874

# %%
## drop 
ds.drop_sel(x = [0])
# Out:
# <xarray.Dataset>
# Dimensions:         (x: 1, y: 2, time: 3)
# Coordinates:
#     lon             (x, y) float64 -99.79 -99.23
#     lat             (x, y) float64 42.63 42.59
#   * time            (time) datetime64[ns] 2014-09-06 2014-09-07 2014-09-08
#     reference_time  datetime64[ns] 2014-09-05
# Dimensions without coordinates: x, y
# Data variables:
#     temperature     (x, y, time) float64 17.32 39.65 16.81 8.022 9.973 10.71
#     precipitation   (x, y, time) float64 5.572 9.004 0.5218 1.863 1.283 8.055

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (x: 2, y: 2, time: 3)
# Coordinates:
#     lon             (x, y) float64 -99.83 -99.32 -99.79 -99.23
#     lat             (x, y) float64 42.25 42.21 42.63 42.59
#   * time            (time) datetime64[ns] 2014-09-06 2014-09-07 2014-09-08
#     reference_time  datetime64[ns] 2014-09-05
# Dimensions without coordinates: x, y
# Data variables:
#     temperature     (x, y, time) float64 8.586 21.33 8.045 ... 8.022 9.973 10.71
#     precipitation   (x, y, time) float64 3.824 9.208 4.681 ... 1.863 1.283 8.055

# %%
ds.drop_dims("time")
# Out:
# <xarray.Dataset>
# Dimensions:         (x: 2, y: 2)
# Coordinates:
#     lon             (x, y) float64 -99.83 -99.32 -99.79 -99.23
#     lat             (x, y) float64 42.25 42.21 42.63 42.59
#     reference_time  datetime64[ns] 2014-09-05
# Dimensions without coordinates: x, y
# Data variables:
#     *empty*
